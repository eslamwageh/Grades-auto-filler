# %%
from grid_functions import *
import ipywidgets as widgets
from IPython.display import display, clear_output
import openpyxl
from openpyxl import Workbook

# %%
selected_method = None
digits_models, symbols_models = load_model()

workbook = Workbook()
sheet = workbook.active
sheet.title = "Student Results"

# Write the header
sheet.append(["ID"] + [f"Q{i+1}" for i in range(100)]) 

def program(selected_method = 'Features + Classifier'):
    img = cv2.imread('start.jpg')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    print(img.shape)
    img = cv2.resize(img, (3000, 3000))
    full_paper = getPerspective(img)
    full_paper = full_paper[100:, :]
    clustered_horizontal, clustered_vertical = getLines(full_paper)
    cells = extractCells(full_paper, clustered_horizontal, clustered_vertical)
    predictCells(cells, digits_models, symbols_models, selected_method, sheet)
    workbook.save("Grades_sheet.xlsx")


program()
# Out:
# Loaded digits models from digits_models.joblib
# {'SVM': LinearSVC(random_state=42)}
# Loaded symbols models from symbols_models.joblib
# (1024, 768, 3)
# Table has 17 rows and 6 columns.
# Extracted 102 cells.
# The digit predicted is: 1
# The digit predicted is: 1
# The digit predicted is: 8
# The digit predicted is: 0
# The digit predicted is: 2
# The digit predicted is: 3
# The digit predicted is: 6
# The digit predicted is: 1
# The symbol predicted is: ['check']
# The symbol predicted is: ['square']
# The digit predicted is: 1
# The digit predicted is: 1
# The digit predicted is: 8
# The digit predicted is: 0
# The digit predicted is: 3
# The digit predicted is: 3
# The digit predicted is: 3
# The digit predicted is: 4
# The symbol predicted is: ['vertical4']
# The symbol predicted is: ['horizontal4']
# The digit predicted is: 1
# The digit predicted is: 1
# The digit predicted is: 8
# The digit predicted is: 0
# The digit predicted is: 1
# The digit predicted is: 2
# The digit predicted is: 8
# The digit predicted is: 5
# The symbol predicted is: ['check']
# The symbol predicted is: ['check']
# The digit predicted is: 1
# The digit predicted is: 1
# The digit predicted is: 4
# The digit predicted is: 0
# The digit predicted is: 1
# The digit predicted is: 5
# The digit predicted is: 5
# The digit predicted is: 6
# The symbol predicted is: ['question']
# The symbol predicted is: ['vertical2']
# The digit predicted is: 1
# The digit predicted is: 1
# The digit predicted is: 8
# The digit predicted is: 0
# The digit predicted is: 1
# The digit predicted is: 1
# The digit predicted is: 4
# The digit predicted is: 6
# The symbol predicted is: ['check']
# The symbol predicted is: ['vertical4']
# The digit predicted is: 1
# The digit predicted is: 1
# The digit predicted is: 8
# The digit predicted is: 0
# The digit predicted is: 0
# The digit predicted is: 5
# The digit predicted is: 6
# The digit predicted is: 1
# The symbol predicted is: ['square']
# The symbol predicted is: ['question']
# The digit predicted is: 1
# The digit predicted is: 1
# The digit predicted is: 4
# The digit predicted is: 0
# The digit predicted is: 0
# The digit predicted is: 1
# The digit predicted is: 1
# The digit predicted is: 6
# The symbol predicted is: ['horizontal2']
# The symbol predicted is: ['check']
# The digit predicted is: 1
# The digit predicted is: 1
# The digit predicted is: 8
# The digit predicted is: 0
# The digit predicted is: 6
# The digit predicted is: 0
# The digit predicted is: 6
# The digit predicted is: 7
# The symbol predicted is: ['empty']
# The symbol predicted is: ['check']
# The digit predicted is: 1
# The digit predicted is: 1
# The digit predicted is: 8
# The digit predicted is: 0
# The digit predicted is: 6
# The digit predicted is: 5
# The digit predicted is: 6
# The digit predicted is: 2
# The symbol predicted is: ['question']
# The symbol predicted is: ['empty']
# The digit predicted is: 2
# The digit predicted is: 1
# The digit predicted is: 0
# The digit predicted is: 0
# The digit predicted is: 0
# The digit predicted is: 1
# The digit predicted is: 1
# The digit predicted is: 6
# The symbol predicted is: ['check']
# The symbol predicted is: ['square']
# The digit predicted is: 1
# The digit predicted is: 1
# The digit predicted is: 8
# The digit predicted is: 0
# The digit predicted is: 5
# The digit predicted is: 5
# The digit predicted is: 1
# The digit predicted is: 5
# The symbol predicted is: ['empty']
# The symbol predicted is: ['empty']
# The digit predicted is: 1
# The digit predicted is: 1
# The digit predicted is: 8
# The digit predicted is: 0
# The digit predicted is: 1
# The digit predicted is: 0
# The digit predicted is: 1
# The digit predicted is: 3
# The symbol predicted is: ['horizontal2']
# The symbol predicted is: ['check']
# The digit predicted is: 1
# The digit predicted is: 1
# The digit predicted is: 8
# The digit predicted is: 0
# The digit predicted is: 7
# The digit predicted is: 7
# The digit predicted is: 0
# The digit predicted is: 4
# The digit predicted is: 5
# The digit predicted is: 5
# The symbol predicted is: ['check']
# The symbol predicted is: ['check']
# The digit predicted is: 1
# The digit predicted is: 1
# The digit predicted is: 8
# The digit predicted is: 0
# The digit predicted is: 2
# The digit predicted is: 1
# The digit predicted is: 2
# The digit predicted is: 4
# The symbol predicted is: ['horizontal3']
# The symbol predicted is: ['vertical3']
# The digit predicted is: 1
# The digit predicted is: 1
# The digit predicted is: 8
# The digit predicted is: 0
# The digit predicted is: 1
# The digit predicted is: 5
# The digit predicted is: 5
# The digit predicted is: 8
# The symbol predicted is: ['check']
# The symbol predicted is: ['question']
# The digit predicted is: 1
# The digit predicted is: 1
# The digit predicted is: 7
# The digit predicted is: 0
# The digit predicted is: 3
# The digit predicted is: 4
# The digit predicted is: 3
# The digit predicted is: 4
# The symbol predicted is: ['square']
# The symbol predicted is: ['empty']
# The digit predicted is: 1
# The digit predicted is: 1
# The digit predicted is: 1
# The digit predicted is: 1
# The digit predicted is: 1
# The digit predicted is: 1
# The digit predicted is: 4
# The symbol predicted is: ['question']
# The symbol predicted is: ['check']
